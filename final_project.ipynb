# %%
import tweepy
import json
import pandas as pd

# %%
auth = tweepy.OAuthHandler('','')
auth.set_access_token('','')

# %%
api = tweepy.API(auth)

# %%
user = api.get_user('MIDASIIITD')

# %%
print('User name ->',user.screen_name,end = '\n\n')
print('no_of_followers ->',user.followers_count,end = '\n\n')
# Out:
# User name -> midasIIITD
#
# no_of_followers -> 233

# %%
result_set_midas = user.timeline(count = 327,truncated = False)
print(result_set_midas[0]._json)
# Out:
# {'created_at': 'Fri Apr 05 16:08:37 +0000 2019', 'id': 1114198161562775553, 'id_str': '1114198161562775553', 'text': 'We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal.… https://t.co/gZwyr7D2Sw', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'midasIIITD', 'name': 'MIDAS IIITD', 'id': 1021355762575073281, 'id_str': '1021355762575073281', 'indices': [71, 82]}], 'urls': [{'url': 'https://t.co/gZwyr7D2Sw', 'expanded_url': 'https://twitter.com/i/web/status/1114198161562775553', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1021355762575073281, 'id_str': '1021355762575073281', 'name': 'MIDAS IIITD', 'screen_name': 'midasIIITD', 'location': 'New Delhi, India', 'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.', 'url': 'https://t.co/Uwg7oSM6mE', 'entities': {'url': {'urls': [{'url': 'https://t.co/Uwg7oSM6mE', 'expanded_url': 'http://midas.iiitd.edu.in/', 'display_url': 'midas.iiitd.edu.in', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 232, 'friends_count': 42, 'listed_count': 0, 'created_at': 'Mon Jul 23 11:26:04 +0000 2018', 'favourites_count': 140, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 327, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 7, 'favorited': False, 'retweeted': False, 'lang': 'en'}

# %%
no_of_tweets_ret = len(result_set_midas)
no_of_status = user.statuses_count
user.statuses_count,no_of_tweets_ret
# Out:
# (327, 200)

# %%
last_id = result_set_midas[-1]._json['id']

# %%
result_set_midas_older = user.timeline(max_id = last_id,count = no_of_status-no_of_tweets_ret )
no_of_tweets_ret_older = len(result_set_midas_older)
no_of_tweets_ret_older
# Out:
# 127

# %%
print(result_set_midas[-1]._json['id'])
print(result_set_midas_older[0]._json['id'])
# Out:
# 1056377151451099137
# 1056377151451099137

# %%
data = []
result = result_set_midas+result_set_midas_older
for i in range(no_of_status):
    data.append(result[i]._json)

# %%
with open('result.json','w') as fp:
    json.dump(data, fp)
fp.close
# Out:
# <function TextIOWrapper.close>

# %%
with open('result.json','r') as fp:
    try:
        data = json.load(fp)
    except:
        print('JSON is not loading')
    fp.close

# %%
len(data)
# Out:
# 327

# %%
coloumn = ['created_at','text','retweet_count','favorite_count','no_of_media']

# %%
data
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Apr 05 16:08:37 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1114198161562775553',
#      'indices': [117, 140],
#      'url': 'https://t.co/gZwyr7D2Sw'}],
#    'user_mentions': [{'id': 1021355762575073281,
#      'id_str': '1021355762575073281',
#      'indices': [71, 82],
#      'name': 'MIDAS IIITD',
#      'screen_name': 'midasIIITD'}]},
#   'favorite_count': 7,
#   'favorited': False,
#   'geo': None,
#   'id': 1114198161562775553,
#   'id_str': '1114198161562775553',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal.… https://t.co/gZwyr7D2Sw',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Apr 05 04:05:11 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'arxiv.org/abs/1904.01596',
#      'expanded_url': 'https://arxiv.org/abs/1904.01596',
#      'indices': [110, 133],
#      'url': 'https://t.co/g7wiegXxDg'}],
#    'user_mentions': [{'id': 399948170,
#      'id_str': '399948170',
#      'indices': [3, 10],
#      'name': 'rob voigt',
#      'screen_name': 'rfpvjr'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1114016105079693312,
#   'id_str': '1114016105079693312',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 16,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 04 20:44:40 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1113905244159660032',
#       'indices': [99, 122],
#       'url': 'https://t.co/M3orvkPYz8'}],
#     'user_mentions': []},
#    'favorite_count': 48,
#    'favorited': False,
#    'geo': None,
#    'id': 1113905244159660032,
#    'id_str': '1113905244159660032',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 16,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv!… https://t.co/M3orvkPYz8',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Oct 28 08:46:01 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'using computational methods to understand the linguistic mechanisms of social problems; NLP, socioling, discourse-pragmatics',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nlp.stanford.edu/robvoigt',
#         'expanded_url': 'http://nlp.stanford.edu/robvoigt',
#         'indices': [0, 22],
#         'url': 'http://t.co/itaef23mZg'}]}},
#     'favourites_count': 238,
#     'follow_request_sent': False,
#     'followers_count': 482,
#     'following': False,
#     'friends_count': 452,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 399948170,
#     'id_str': '399948170',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10,
#     'location': 'palo alto, ca',
#     'name': 'rob voigt',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1739575943/Voigt_Robert_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1739575943/Voigt_Robert_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'rfpvjr',
#     'statuses_count': 67,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/itaef23mZg',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @rfpvjr: Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv! https://t.co/g7wiegXxDg\nThis…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Apr 05 04:04:43 +0000 2019',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/ccX4Uhxjn8',
#      'expanded_url': 'https://twitter.com/kdnuggets/status/1114014848369799169/photo/1',
#      'id': 1114014846817796099,
#      'id_str': '1114014846817796099',
#      'indices': [75, 98],
#      'media_url': 'http://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#      'media_url_https': 'https://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#      'sizes': {'large': {'h': 300, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 300, 'resize': 'fit', 'w': 640},
#       'small': {'h': 300, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1114014848369799169,
#      'source_status_id_str': '1114014848369799169',
#      'source_user_id': 20167623,
#      'source_user_id_str': '20167623',
#      'type': 'photo',
#      'url': 'https://t.co/ccX4Uhxjn8'}],
#    'symbols': [],
#    'urls': [{'display_url': 'buff.ly/2K7XvvN',
#      'expanded_url': 'https://buff.ly/2K7XvvN',
#      'indices': [51, 74],
#      'url': 'https://t.co/Z1m0AzlfVv'}],
#    'user_mentions': [{'id': 20167623,
#      'id_str': '20167623',
#      'indices': [3, 13],
#      'name': 'KDnuggets',
#      'screen_name': 'kdnuggets'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ccX4Uhxjn8',
#      'expanded_url': 'https://twitter.com/kdnuggets/status/1114014848369799169/photo/1',
#      'id': 1114014846817796099,
#      'id_str': '1114014846817796099',
#      'indices': [75, 98],
#      'media_url': 'http://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#      'media_url_https': 'https://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#      'sizes': {'large': {'h': 300, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 300, 'resize': 'fit', 'w': 640},
#       'small': {'h': 300, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1114014848369799169,
#      'source_status_id_str': '1114014848369799169',
#      'source_user_id': 20167623,
#      'source_user_id_str': '20167623',
#      'type': 'photo',
#      'url': 'https://t.co/ccX4Uhxjn8'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1114015987395854336,
#   'id_str': '1114015987395854336',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 10,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Apr 05 04:00:11 +0000 2019',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/ccX4Uhxjn8',
#       'expanded_url': 'https://twitter.com/kdnuggets/status/1114014848369799169/photo/1',
#       'id': 1114014846817796099,
#       'id_str': '1114014846817796099',
#       'indices': [60, 83],
#       'media_url': 'http://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#       'media_url_https': 'https://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#       'sizes': {'large': {'h': 300, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 300, 'resize': 'fit', 'w': 640},
#        'small': {'h': 300, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ccX4Uhxjn8'}],
#     'symbols': [],
#     'urls': [{'display_url': 'buff.ly/2K7XvvN',
#       'expanded_url': 'https://buff.ly/2K7XvvN',
#       'indices': [36, 59],
#       'url': 'https://t.co/Z1m0AzlfVv'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ccX4Uhxjn8',
#       'expanded_url': 'https://twitter.com/kdnuggets/status/1114014848369799169/photo/1',
#       'id': 1114014846817796099,
#       'id_str': '1114014846817796099',
#       'indices': [60, 83],
#       'media_url': 'http://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#       'media_url_https': 'https://pbs.twimg.com/media/D3XGmdMWAAM7bXv.png',
#       'sizes': {'large': {'h': 300, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 300, 'resize': 'fit', 'w': 640},
#        'small': {'h': 300, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ccX4Uhxjn8'}]},
#    'favorite_count': 19,
#    'favorited': False,
#    'geo': None,
#    'id': 1114014848369799169,
#    'id_str': '1114014848369799169',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 10,
#    'retweeted': False,
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'text': 'Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Feb 05 17:37:26 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Covering #AI, #Analytics, #BigData, #DataMining, #DataScience #MachineLearning, #DeepLearning.  Founded by Gregory Piatetsky-Shapiro.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'kdnuggets.com',
#         'expanded_url': 'https://www.kdnuggets.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/pTYBq6ncsT'}]}},
#     'favourites_count': 642,
#     'follow_request_sent': False,
#     'followers_count': 144341,
#     'following': False,
#     'friends_count': 413,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 20167623,
#     'id_str': '20167623',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 6093,
#     'location': 'Brookline, MA, USA',
#     'name': 'KDnuggets',
#     'notifications': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20167623/1476546748',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'kdnuggets',
#     'statuses_count': 55660,
#     'time_zone': None,
#     'translator_type': 'regular',
#     'url': 'https://t.co/pTYBq6ncsT',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @kdnuggets: Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Apr 03 18:31:53 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 118263124,
#      'id_str': '118263124',
#      'indices': [3, 15],
#      'name': 'Stanford NLP Group',
#      'screen_name': 'stanfordnlp'},
#     {'id': 18036441,
#      'id_str': '18036441',
#      'indices': [31, 40],
#      'name': 'Stanford University',
#      'screen_name': 'Stanford'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1113509442849525760,
#   'id_str': '1113509442849525760',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 55,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 03 17:07:30 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1113488206417104897',
#       'indices': [117, 140],
#       'url': 'https://t.co/Zv9wvfNLkM'}],
#     'user_mentions': [{'id': 18036441,
#       'id_str': '18036441',
#       'indices': [14, 23],
#       'name': 'Stanford University',
#       'screen_name': 'Stanford'}]},
#    'favorite_count': 222,
#    'favorited': False,
#    'geo': None,
#    'id': 1113488206417104897,
#    'id_str': '1113488206417104897',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 55,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—… https://t.co/Zv9wvfNLkM',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Feb 28 03:28:05 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Computational Linguistics—Natural Language—Machine Learning—Deep Learning. And misc technology from Silicon Valley. (@chrmanning, @jurafsky & @percyliang)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nlp.stanford.edu',
#         'expanded_url': 'http://nlp.stanford.edu/',
#         'indices': [0, 22],
#         'url': 'http://t.co/OK65AqppWC'}]}},
#     'favourites_count': 2,
#     'follow_request_sent': False,
#     'followers_count': 70482,
#     'following': False,
#     'friends_count': 98,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 118263124,
#     'id_str': '118263124',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1608,
#     'location': 'Stanford, CA, USA',
#     'name': 'Stanford NLP Group',
#     'notifications': False,
#     'profile_background_color': '8C1515',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/118263124/1524181760',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/897182721272799232/0CplRl36_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/897182721272799232/0CplRl36_normal.jpg',
#     'profile_link_color': '8C1515',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'stanfordnlp',
#     'statuses_count': 5435,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/OK65AqppWC',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @stanfordnlp: What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—subword…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Apr 03 17:04:32 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 4783690002,
#      'id_str': '4783690002',
#      'indices': [3, 14],
#      'name': 'DeepMind',
#      'screen_name': 'DeepMindAI'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1113487457780215808,
#   'id_str': '1113487457780215808',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 841,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 03 12:38:17 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1113420454860083201',
#       'indices': [116, 139],
#       'url': 'https://t.co/SZRSMvEeO3'}],
#     'user_mentions': []},
#    'favorite_count': 2338,
#    'favorited': False,
#    'geo': None,
#    'id': 1113420454860083201,
#    'id_str': '1113420454860083201',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 841,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the… https://t.co/SZRSMvEeO3",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jan 19 13:46:08 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Founded in 2010.  Building Artificial General Intelligence. The creators of #AlphaGo and Atari DQN',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'deepmind.com',
#         'expanded_url': 'http://www.deepmind.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/8B3TFFIGoP'}]}},
#     'favourites_count': 224,
#     'follow_request_sent': False,
#     'followers_count': 224948,
#     'following': False,
#     'friends_count': 110,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 4783690002,
#     'id_str': '4783690002',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3246,
#     'location': 'London, UK',
#     'name': 'DeepMind',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783690002/1484305927',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/692405474986164224/NzcXa05I_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692405474986164224/NzcXa05I_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DeepMindAI',
#     'statuses_count': 822,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/8B3TFFIGoP',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "RT @DeepMindAI: Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the abilitie…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Apr 03 09:03:40 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'facebook.com/722677142/post…',
#      'expanded_url': 'https://www.facebook.com/722677142/posts/10155878847627143/',
#      'indices': [90, 113],
#      'url': 'https://t.co/1WNcSeQLZe'}],
#    'user_mentions': [{'id': 48008938,
#      'id_str': '48008938',
#      'indices': [3, 10],
#      'name': 'Yann LeCun',
#      'screen_name': 'ylecun'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1113366445231104001,
#   'id_str': '1113366445231104001',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 16,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 03 06:01:47 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'facebook.com/722677142/post…',
#       'expanded_url': 'https://www.facebook.com/722677142/posts/10155878847627143/',
#       'indices': [78, 101],
#       'url': 'https://t.co/1WNcSeQLZe'}],
#     'user_mentions': []},
#    'favorite_count': 150,
#    'favorited': False,
#    'geo': None,
#    'id': 1113320674452439040,
#    'id_str': '1113320674452439040',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 16,
#    'retweeted': False,
#    'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    'text': 'Congratulations Jitendra Malik !\n\nAwards are raining on FAIRies these days... https://t.co/1WNcSeQLZe',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 17 16:05:51 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'yann.lecun.com',
#         'expanded_url': 'http://yann.lecun.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/rBCcBh4hwE'}]}},
#     'favourites_count': 1951,
#     'follow_request_sent': False,
#     'followers_count': 134376,
#     'following': False,
#     'friends_count': 213,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 48008938,
#     'id_str': '48008938',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2527,
#     'location': 'New York',
#     'name': 'Yann LeCun',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2387565623/7gew8nz1z7ik1ch148so_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2387565623/7gew8nz1z7ik1ch148so_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ylecun',
#     'statuses_count': 3186,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/rBCcBh4hwE',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @ylecun: Congratulations Jitendra Malik !\n\nAwards are raining on FAIRies these days... https://t.co/1WNcSeQLZe',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Apr 03 07:46:02 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2227868629,
#      'id_str': '2227868629',
#      'indices': [3, 13],
#      'name': 'IIIT Delhi',
#      'screen_name': 'IIITDelhi'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1113346906007265280,
#   'id_str': '1113346906007265280',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 03 07:42:27 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1113346005515350016',
#       'indices': [117, 140],
#       'url': 'https://t.co/flV6vANqqG'}],
#     'user_mentions': []},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 1113346005515350016,
#    'id_str': '1113346005515350016',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Another chance to take admission in the Ph.D. program in IIIT Delhi. \nAdmissions open for Ph.D. program mathematics… https://t.co/flV6vANqqG',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Dec 03 07:27:35 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Official Twitter handle of Indraprastha Institute of Information Technology, Delhi (IIIT-D)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'iiitd.ac.in',
#         'expanded_url': 'http://www.iiitd.ac.in',
#         'indices': [0, 22],
#         'url': 'http://t.co/Shz3rGJG0f'}]}},
#     'favourites_count': 1309,
#     'follow_request_sent': False,
#     'followers_count': 1569,
#     'following': True,
#     'friends_count': 47,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2227868629,
#     'id_str': '2227868629',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 40,
#     'location': 'New Delhi, India',
#     'name': 'IIIT Delhi',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2227868629/1466086346',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/710727346148409344/88A6YRY2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/710727346148409344/88A6YRY2_normal.jpg',
#     'profile_link_color': '3FADA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'IIITDelhi',
#     'statuses_count': 1964,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/Shz3rGJG0f',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @IIITDelhi: Another chance to take admission in the Ph.D. program in IIIT Delhi. \nAdmissions open for Ph.D. program mathematics \n\nLog on…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Apr 02 04:20:13 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1112932724090851328',
#      'indices': [117, 140],
#      'url': 'https://t.co/4lCcAmwBKc'}],
#    'user_mentions': [{'id': 1021355762575073281,
#      'id_str': '1021355762575073281',
#      'indices': [5, 16],
#      'name': 'MIDAS IIITD',
#      'screen_name': 'midasIIITD'}]},
#   'favorite_count': 8,
#   'favorited': False,
#   'geo': None,
#   'id': 1112932724090851328,
#   'id_str': '1112932724090851328',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Dear @midasIIITD internship candidates who have submitted their solutions to the task, we have sent you an email re… https://t.co/4lCcAmwBKc',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Apr 02 02:44:54 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1112908735930908673',
#      'indices': [117, 140],
#      'url': 'https://t.co/ODYKLC8z0s'}],
#    'user_mentions': [{'id': 1108061173130223616,
#      'id_str': '1108061173130223616',
#      'indices': [44, 56],
#      'name': 'IEEE BigMM 2019',
#      'screen_name': 'IEEEBigMM19'}]},
#   'favorite_count': 5,
#   'favorited': False,
#   'geo': None,
#   'id': 1112908735930908673,
#   'id_str': '1112908735930908673',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Looking forward to your paper submission to @IEEEBigMM19. \n\nImportant Dates:\nRegular Paper: 11:59pm PST, May 10, 20… https://t.co/ODYKLC8z0s',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
# ...
#   'text': 'MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 24 10:12:34 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/IIITDelhi/stat…',
#      'expanded_url': 'https://twitter.com/IIITDelhi/status/1021697165389783040',
#      'indices': [45, 68],
#      'url': 'https://t.co/IRRTtIpC6D'}],
#    'user_mentions': [{'id': 2227868629,
#      'id_str': '2227868629',
#      'indices': [33, 43],
#      'name': 'IIIT Delhi',
#      'screen_name': 'IIITDelhi'}]},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': None,
#   'id': 1021699654805729280,
#   'id_str': '1021699654805729280',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jul 24 10:02:41 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'midas.iiitd.edu.in',
#       'expanded_url': 'http://midas.iiitd.edu.in/',
#       'indices': [58, 81],
#       'url': 'https://t.co/2dKiRHVilK'},
#      {'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1021697165389783040',
#       'indices': [117, 140],
#       'url': 'https://t.co/okrg1X1I97'}],
#     'user_mentions': [{'id': 1021355762575073281,
#       'id_str': '1021355762575073281',
#       'indices': [41, 52],
#       'name': 'MIDAS IIITD',
#       'screen_name': 'midasIIITD'}]},
#    'favorite_count': 35,
#    'favorited': False,
#    'geo': None,
#    'id': 1021697165389783040,
#    'id_str': '1021697165389783040',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'We are pleased to announce the launch of @midasIIITD lab (https://t.co/2dKiRHVilK). It is founded by Dr. Rajiv Ratn… https://t.co/okrg1X1I97',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Dec 03 07:27:35 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Official Twitter handle of Indraprastha Institute of Information Technology, Delhi (IIIT-D)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'iiitd.ac.in',
#         'expanded_url': 'http://www.iiitd.ac.in',
#         'indices': [0, 22],
#         'url': 'http://t.co/Shz3rGJG0f'}]}},
#     'favourites_count': 1309,
#     'follow_request_sent': False,
#     'followers_count': 1569,
#     'following': True,
#     'friends_count': 47,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2227868629,
#     'id_str': '2227868629',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 40,
#     'location': 'New Delhi, India',
#     'name': 'IIIT Delhi',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2227868629/1466086346',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/710727346148409344/88A6YRY2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/710727346148409344/88A6YRY2_normal.jpg',
#     'profile_link_color': '3FADA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'IIITDelhi',
#     'statuses_count': 1964,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/Shz3rGJG0f',
#     'utc_offset': None,
#     'verified': False}},
#   'quoted_status_id': 1021697165389783040,
#   'quoted_status_id_str': '1021697165389783040',
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'It feels great to be the part of @IIITDelhi. https://t.co/IRRTtIpC6D',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jul 24 09:46:26 +0000 2018',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/yx2u2Vs36Z',
#      'expanded_url': 'https://twitter.com/midasIIITD/status/1021693076337618944/photo/1',
#      'id': 1021693071342223360,
#      'id_str': '1021693071342223360',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/Di3Ib2rUwAAklmz.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Di3Ib2rUwAAklmz.jpg',
#      'sizes': {'large': {'h': 960, 'resize': 'fit', 'w': 1357},
#       'medium': {'h': 849, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 481, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/yx2u2Vs36Z'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 104182041,
#      'id_str': '104182041',
#      'indices': [11, 21],
#      'name': 'anoop ratn',
#      'screen_name': 'toonzratn'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/yx2u2Vs36Z',
#      'expanded_url': 'https://twitter.com/midasIIITD/status/1021693076337618944/photo/1',
#      'id': 1021693071342223360,
#      'id_str': '1021693071342223360',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/Di3Ib2rUwAAklmz.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Di3Ib2rUwAAklmz.jpg',
#      'sizes': {'large': {'h': 960, 'resize': 'fit', 'w': 1357},
#       'medium': {'h': 849, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 481, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/yx2u2Vs36Z'}]},
#   'favorite_count': 4,
#   'favorited': False,
#   'geo': None,
#   'id': 1021693076337618944,
#   'id_str': '1021693076337618944',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Thank you, @toonzratn for designing the logo of MIDAS. https://t.co/yx2u2Vs36Z',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jul 23 16:25:05 +0000 2018',
#   'entities': {'hashtags': [{'indices': [83, 89], 'text': 'MIDAS'},
#     {'indices': [90, 96], 'text': 'IIITD'}],
#    'symbols': [],
#    'urls': [{'display_url': 'facebook.com/midasIIITD',
#      'expanded_url': 'https://www.facebook.com/midasIIITD',
#      'indices': [58, 81],
#      'url': 'https://t.co/CRaw6KQPSf'},
#     {'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1021431011970670592',
#      'indices': [98, 121],
#      'url': 'https://t.co/0gj73NnlGc'}],
#    'user_mentions': []},
#   'favorite_count': 3,
#   'favorited': False,
#   'geo': None,
#   'id': 1021431011970670592,
#   'id_str': '1021431011970670592',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'We are on Facebook too. Like our page to get our updates. https://t.co/CRaw6KQPSf\n\n#MIDAS #IIITD… https://t.co/0gj73NnlGc',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#        'expanded_url': 'http://midas.iiitd.edu.in/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Uwg7oSM6mE'}]}},
#    'favourites_count': 140,
#    'follow_request_sent': False,
#    'followers_count': 232,
#    'following': True,
#    'friends_count': 42,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'MIDAS IIITD',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'midasIIITD',
#    'statuses_count': 327,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Uwg7oSM6mE',
#    'utc_offset': None,
#    'verified': False}}]

# %%
tweet = [['' for i in range(len(coloumn))] for j in range(no_of_status)]

# %%
for i in range(no_of_status):
    for j in range(len(coloumn)-1):
        tweet[i][j] = data[i][coloumn[j]]
    try:
        tweet[i][-1] = len([data[i]['entities']['media']])
    except:
        tweet[i][-1] = 'None'

# %%
d = pd.DataFrame(tweet,columns = coloumn)

# %%
d
# Out:
#                          created_at  \
# 0    Fri Apr 05 16:08:37 +0000 2019
# 1    Fri Apr 05 04:05:11 +0000 2019
# 2    Fri Apr 05 04:04:43 +0000 2019
# 3    Wed Apr 03 18:31:53 +0000 2019
# 4    Wed Apr 03 17:04:32 +0000 2019
# 5    Wed Apr 03 09:03:40 +0000 2019
# 6    Wed Apr 03 07:46:02 +0000 2019
# 7    Tue Apr 02 04:20:13 +0000 2019
# 8    Tue Apr 02 02:44:54 +0000 2019
# 9    Tue Apr 02 02:35:44 +0000 2019
# 10   Mon Apr 01 06:53:08 +0000 2019
# 11   Sun Mar 31 10:21:24 +0000 2019
# 12   Fri Mar 29 19:43:24 +0000 2019
# 13   Fri Mar 29 17:16:40 +0000 2019
# 14   Fri Mar 29 17:04:30 +0000 2019
# 15   Fri Mar 29 17:03:29 +0000 2019
# 16   Fri Mar 29 17:02:24 +0000 2019
# 17   Fri Mar 29 05:35:22 +0000 2019
# 18   Thu Mar 28 16:55:01 +0000 2019
# 19   Thu Mar 28 16:54:37 +0000 2019
# 20   Wed Mar 27 16:09:09 +0000 2019
# 21   Wed Mar 27 11:53:40 +0000 2019
# 22   Tue Mar 26 18:12:27 +0000 2019
# 23   Tue Mar 26 05:54:49 +0000 2019
# 24   Tue Mar 26 05:50:10 +0000 2019
# 25   Mon Mar 25 13:01:57 +0000 2019
# 26   Sun Mar 24 18:44:01 +0000 2019
# 27   Sun Mar 24 18:26:02 +0000 2019
# 28   Sun Mar 24 11:34:27 +0000 2019
# 29   Sun Mar 24 06:23:37 +0000 2019
# ..                              ...
# 297  Thu Aug 09 10:17:53 +0000 2018
# 298  Thu Aug 09 05:59:57 +0000 2018
# 299  Wed Aug 08 11:30:56 +0000 2018
# 300  Wed Aug 08 05:53:48 +0000 2018
# 301  Wed Aug 08 05:45:58 +0000 2018
# 302  Tue Aug 07 07:16:33 +0000 2018
# 303  Tue Aug 07 02:05:12 +0000 2018
# 304  Tue Aug 07 01:58:49 +0000 2018
# 305  Tue Aug 07 01:50:33 +0000 2018
# 306  Mon Aug 06 17:48:23 +0000 2018
# 307  Mon Aug 06 17:46:59 +0000 2018
# 308  Mon Aug 06 06:06:47 +0000 2018
# 309  Fri Aug 03 05:56:33 +0000 2018
# 310  Wed Aug 01 11:47:15 +0000 2018
# 311  Wed Aug 01 11:20:07 +0000 2018
# 312  Wed Aug 01 05:06:47 +0000 2018
# 313  Tue Jul 31 12:11:52 +0000 2018
# 314  Tue Jul 31 02:06:26 +0000 2018
# 315  Mon Jul 30 07:30:51 +0000 2018
# 316  Sat Jul 28 11:07:11 +0000 2018
# 317  Sat Jul 28 06:14:09 +0000 2018
# 318  Sat Jul 28 06:13:48 +0000 2018
# 319  Sat Jul 28 04:08:21 +0000 2018
# 320  Fri Jul 27 06:46:44 +0000 2018
# 321  Fri Jul 27 04:07:31 +0000 2018
# 322  Wed Jul 25 05:14:35 +0000 2018
# 323  Tue Jul 24 10:33:23 +0000 2018
# 324  Tue Jul 24 10:12:34 +0000 2018
# 325  Tue Jul 24 09:46:26 +0000 2018
# 326  Mon Jul 23 16:25:05 +0000 2018
#
#                                                   text  retweet_count  \
# 0    We have emailed the task details to all candid...              1
# 1    RT @rfpvjr: Our NAACL paper on polarization in...             16
# 2    RT @kdnuggets: Effective Transfer Learning For...             10
# 3    RT @stanfordnlp: What’s new in @Stanford CS224...             55
# 4    RT @DeepMindAI: Today we're releasing a large-...            841
# 5    RT @ylecun: Congratulations Jitendra Malik !\n...             16
# 6    RT @IIITDelhi: Another chance to take admissio...              4
# 7    Dear @midasIIITD internship candidates who hav...              1
# 8    Looking forward to your paper submission to @I...              1
# 9    RT @ngrams: Reproducibility in multimedia rese...              7
# 10   Online application for https://t.co/DJFDrQsHZP...              1
# 11   RT @ACMMM19: A final reminder of the Reproduci...             10
# 12   RT @isarth23: Thanks for the support and help ...              2
# 13   Since SemEval-2019 will be held June 6-7, 2019...              1
# 14   +@aggarwal_kartik.\nCongrats! Wish you many mo...              0
# 15   RT @aggarwal_kartik: Our work (@midasIIITD ) a...              1
# 16   Congratulations! @midasIIITD team, @isarth23 @...              1
# 17   @EEMLcommunity @radamihalcea too many deadline...              0
# 18   RT @stanfordnlp: CS224N Natural Language Proce...            710
# 19   RT @ylecun: Learn PyTorch by running on Google...            157
# 20   Dr. Vineeth N Balasubramanian will present a T...              1
# 21   RT @ylecun: I am extremely honored to be the r...           1544
# 22   Thanks to all shortlisted candidates for submi...              1
# 23   @IEEEBigMM19 @ACMMM19 and 6 days left for work...              0
# 24   RT @IEEEBigMM19: Hurry Up!\n6 Days left for Ab...              3
# 25   Congratulations @midasIIITD students Simra Sha...              1
# 26   The last date for submitting a solution for th...              3
# 27   RT @IIITDelhi: @IIITDelhi invites application ...              4
# 28   One more week is left to submit the workshop p...              0
# 29   RT @IEEEBigMM19: We are honored to have Dr. Ch...              5
# ..                                                 ...            ...
# 297  RT @kdnuggets: Ultimate Guide to Getting Start...            111
# 298  RT @TensorFlow: TensorFlow 1.10.0 has been rel...            265
# 299  @midasIIITD is looking for motivated IIITD MTe...              1
# 300  @IIITDelhi @ponguru @RatnRajiv The results of ...              1
# 301  RT @IIITDelhi: @midasIIITD has secured rank 1 ...              1
# 302  RT @kdnuggets: Comparison of Top 6 Python NLP ...             40
# 303  Check more details of the 20th IEEE Internatio...              1
# 304  MR2AMC@ISM 2018 will be organized by @RatnRaji...              1
# 305  Our workshop proposal named, "MR2AMC: Multimod...              1
# 306  @NUSComputing Congratulations Abdelhak and Pro...              0
# 307  RT @goodfellow_ian: One of the most anticipate...            103
# 308     @the_dhumketu Great to have you in @midasIIITD              0
# 309  Congratulation @soujanyaporia for being appoin...              1
# 310  @IIITDelhi @the_dhumketu Thanks team @midasIII...              1
# 311  RT @IIITDelhi: Congratulations @midasIIITD int...              4
# 312  RT @learning_pt: Profile of the 5 Indian under...              4
# 313  Have a look at the list of accepted papers in ...              0
# 314  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...            264
# 315  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...              2
# 316  RT @ylecun: Jitendra Malik, who directs FAIR-M...             57
# 317  RT @kdnuggets: .@Bloomberg launches free cours...            105
# 318  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...              7
# 319  RT @IIITDelhi: We are delighted to announce th...              6
# 320  Get ready for the annual technical fest of @II...              2
# 321  Congratulations Dr. @RatnRajiv and team @midas...              2
# 322  Congratulations MIDAS @midasIIITD intern Prakh...              1
# 323    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm              1
# 324  It feels great to be the part of @IIITDelhi. h...              1
# 325  Thank you, @toonzratn for designing the logo o...              1
# 326  We are on Facebook too. Like our page to get o...              1
#
#      favorite_count no_of_media
# 0                 7        None
# 1                 0        None
# 2                 0           1
# 3                 0        None
# 4                 0        None
# 5                 0        None
# 6                 0        None
# 7                 8        None
# 8                 5        None
# 9                 0        None
# 10                6        None
# 11                0        None
# 12                0        None
# 13                9        None
# 14                2        None
# 15                0        None
# 16                9        None
# 17                0        None
# 18                0        None
# 19                0        None
# 20                4        None
# 21                0        None
# 22                5        None
# 23                2        None
# 24                0        None
# 25               18        None
# 26                8        None
# 27                0        None
# 28                4        None
# 29                0        None
# ..              ...         ...
# 297               0           1
# 298               0        None
# 299               2        None
# 300               3           1
# 301               0        None
# 302               0           1
# 303               1        None
# 304               1        None
# 305               1        None
# 306               0        None
# 307               0           1
# 308               0        None
# 309               6        None
# 310               5           1
# 311               0        None
# 312               0        None
# 313               1        None
# 314               0        None
# 315               0        None
# 316               0        None
# 317               0        None
# 318               0        None
# 319               0        None
# 320               3        None
# 321               8        None
# 322               5        None
# 323               2        None
# 324               2        None
# 325               4           1
# 326               3        None
#
# [327 rows x 5 columns]

# %%
d.columns
# Out:
# Index(['created_at', 'text', 'retweet_count', 'favorite_count'], dtype='object')
